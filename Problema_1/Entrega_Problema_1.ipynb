# %%
import data_load as dl


#print(dl.y_proba1)
#print(dl.target_test.shape)

#y_proba1 = dl.y_proba1[:,1]
dl.mostrar_datos()
# Out:
# 0.48 0.1 1
# 0.62 0.1 0.1
# 0.62 10 0.1
# 0.62 0.1 0.1
# 0.62 0.1 0.01
# Sin rebalanceo:
# Undersampling:
# Oversampling Duplicate:
# Oversampling Smote:
# Weighted Classes:
#                    Modelo  Accuracy  Precision  Recall  F-Score    auc-pr
# 0          Sin rebalanceo     0.841      0.714   0.357     0.48  0.515109  \
# 1           Undersampling     0.855      0.667   0.571     0.62  0.518665
# 2  Oversampling duplicate     0.855      0.667   0.571     0.62  0.500738
# 3      Oversampling smote     0.855      0.667   0.571     0.62  0.485526
# 4       Cost re weighting     0.855      0.667   0.571     0.62  0.488868
#
#     auc-roc
# 0  0.790909
# 1  0.768831
# 2  0.790909
# 3  0.784416
# 4  0.776623

# %%
print("Es notable la diferencia de resultados bajo el mismo modelo pero cambiando el sampleo de datos. En particular la mejor tecnica fue la de oversampling-smote. Dado que esta tiene el mejor auc-pr y manteniendo bien las otras metricas en comparacion con los otros modelos. Este dataset contaba con una gran disparidad en la cantidad de casos negativos vs positivos. Por esto es que las tecnicas de sampleo afectan los resultados del modelo. ")
# Out:
# Es notable la diferencia de resultados bajo el mismo modelo pero cambiando el sampleo de datos. En particular la mejor tecnica fue la de oversampling-smote. Dado que esta tiene el mejor auc-pr y manteniendo bien las otras metricas en comparacion con los otros modelos. Este dataset contaba con una gran disparidad en la cantidad de casos negativos vs positivos. Por esto es que las tecnicas de sampleo afectan los resultados del modelo.
