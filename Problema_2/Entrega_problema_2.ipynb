# %%
import data_load2 as dl2
# Out:
# Counter({0: 43018, 2: 28277, 1: 3705})
# 0.4252380525618527 4 3 0.0 10000000.0
# 0.42436498932419364 0.01 0.1
# metricas para LDA:
# Matriz de confusión:
#  [[15035  4812  1523]
#  [  152   218    93]
#  [  835  1793   907]]
# Accuracy: 0.6370230211289813
# Precision por clase: [0.9383972  0.03195075 0.35949267]
# Recall por clase: [0.70355639 0.47084233 0.25657709]
# F1-Score por clase: [0.80418271 0.05984079 0.29943876]
# Clase 0:
# Clase 1:
# Clase 2:
# AUC-ROC (macro): -0.77
# AUC-PR (macro): -0.46
# metricas para random forest:
# Matriz de confusión:
#  [[16945     0  4425]
#  [  228     0   235]
#  [ 1320     0  2215]]
# Accuracy: 0.7552822453484705
# Precision por clase: [0.91629265 0.         0.32218182]
# Recall por clase: [0.79293402 0.         0.62659123]
# F1-Score por clase: [0.8501618  0.         0.42555235]
# Clase 0:
# Clase 1:
# Clase 2:
# AUC-ROC (macro): -0.64
# AUC-PR (macro): -0.16
# Metricas para regresion logistica:
# Matriz de confusión:
# ...

# %%
print("El problema_2 cuenta con un dataset muy grande, multiclase y un desbalance significativo. Por esta razon opte por hacer undersampling dado que seria muy costoso para los calculos de los modelos haciendo oversampling. Hice LDA, Random Forest y Regresion Logistica. El peor modelo aparenta ser el Random Forest dado que este no detecta la clase 1. Y la mejor es la Regresion Logistica. Ya que es capaz de reconocer la clase 1. Y tiene el mejor valor de F1 para la clase 0 y 2. Es importante notar que para este modelo opte por ponerle un threshold a cada clase.  ")
# Out:
# El problema_2 cuenta con un dataset muy grande, multiclase y un desbalance significativo. Por esta razon opte por hacer undersampling dado que seria muy costoso para los calculos de los modelos haciendo oversampling. Hice LDA, Random Forest y Regresion Logistica. El peor modelo aparenta ser el Random Forest dado que este no detecta la clase 1. Y la mejor es la Regresion Logistica. Ya que es capaz de reconocer la clase 1. Y tiene el mejor valor de F1 para la clase 0 y 2. Es importante notar que para este modelo opte por ponerle un threshold a cada clase.
